# %% [markdown]
# # Caminante aleatorio
#
# Este consiste en lanzar una moneda a cada paso y tomar una decisión hacia donde caminar. En este notebook se presenta una manera muy sencilla de hacerlo.

# %% [markdown]
# # Caminante aleatorio
#
# Prueba de cambios en Git ajeno

# %%
from pylab import *
# %matplotlib inline

# %%
trayectoria = zeros(3000)
posicion = 0
for n in range(len(trayectoria)):
    trayectoria[n]=posicion
    volado = rand()
    if volado < 0.5:
        posicion = posicion - 1
    else:
        posicion = posicion + 1
plot(range(len(trayectoria)),trayectoria)
show()
